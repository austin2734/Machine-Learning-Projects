# %%
# Imports pandas library to be used to create dataframe for assignment
import pandas as pd

# Creates dataframe from winequality-red.csv file
red_wines = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
# Displays first six rows of datasets
red_wines.head(6)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# ...

# %%
# Displays number of rows and columns in dataset
red_wines.shape
# Out:
# (1599, 12)

# %%
# Calculates standard deviation of each wine category, shows how disperse values are in dataset
red_wines.std()
# Out:
# fixed acidity            1.741096
# volatile acidity         0.179060
# citric acid              0.194801
# residual sugar           1.409928
# chlorides                0.047065
# free sulfur dioxide     10.460157
# total sulfur dioxide    32.895324
# density                  0.001887
# pH                       0.154386
# sulphates                0.169507
# alcohol                  1.065668
# quality                  0.807569
# dtype: float64

# %%
# Displays summary of numerical attributes of dataset
red_wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Displays attributes and datatypes of attributes 
red_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Displays labels and datatype of labels 
wines['quality'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_868\1478473824.py in <module>
#       1 # Displays labels and datatype of labels
# ----> 2 wines['quality'].value_counts()
#
# NameError: name 'wines' is not defined

# %%
# Creates copy of orginal datafram containing only its feaatures and displays first 5 rows of new dataframe

red_wine_features = red_wines[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                              'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                              'pH', 'sulphates', 'alcohol']]
red_wine_features.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
# imports matplotlib library to be used in plot creation
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# error handling 
import warnings
warnings.filterwarnings('ignore')

# %%
# Creates and displays scatter plot of the alcohol and pH features of dataset
red_wines.plot.scatter(x = 'alcohol', y = 'pH')
plt.title('Scatter plot of alcohol percentage and pH levels of the wines')
plt.show()

# %%
# Displays scatter matrix of five of the features from the red wine dataset
fiveFeatures = red_wines[['alcohol', 'pH', 'fixed acidity', 'chlorides', 'density' ]]
pd.plotting.scatter_matrix(fiveFeatures, alpha=0.2)
plt.show()

# %%
# Displays plot of my preference
twoFeatures = red_wines[['fixed acidity', 'free sulfur dioxide']]
twoFeatures.plot.box()
plt.title('Box plots compairing fixed acidity and free sulfur dioxide')
plt.show()
